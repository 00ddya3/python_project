# %%
import matplotlib.pyplot as plt

plt.plot([10,20,30,40])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
COLOR_ORANGE = '#ED7D31'
COLOR_BLUE = '#5B9BD5'
SQUARE_MARKER = 's' # Square
SOLID_LINE = '-' #':’
DASHED_LINE = '--' #'--'
plt.plot([10, 20, 30, 40], color=COLOR_ORANGE, 
marker=SQUARE_MARKER, linestyle=DASHED_LINE,
markersize = 6)
plt.show()

# %%
import random
import matplotlib.pyplot as plt
dice = []
for i in range(10) :
    dice.append(random.randint(1,6))
print(dice)
plt.hist(dice)
plt.show()
# Out:
# [4, 1, 1, 5, 6, 4, 1, 4, 2, 6]

# %%
import matplotlib.font_manager as fm

font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')
print(font_list)
# Out:
# ['C:\\Windows\\Fonts\\ebrimabd.ttf', 'C:\\Windows\\Fonts\\ARIALNB.TTF', 'C:\\Windows\\Fonts\\NirmalaB.ttf', 'C:\\Windows\\Fonts\\verdanaz.ttf', 'C:\\Windows\\Fonts\\LeelaUIb.ttf', 'C:\\Windows\\Fonts\\LTYPEB.TTF', 'C:\\Windows\\Fonts\\LEELAWDB.TTF', 'C:\\Windows\\Fonts\\holomdl2.ttf', 'C:\\Windows\\Fonts\\batang.ttc', 'C:\\Windows\\Fonts\\GOUDYSTO.TTF', 'C:\\Windows\\Fonts\\Candarab.ttf', 'C:\\Windows\\Fonts\\RAVIE.TTF', 'C:\\Windows\\Fonts\\seguibl.ttf', 'C:\\Windows\\Fonts\\ITCKRIST.TTF', 'C:\\Windows\\Fonts\\ERASDEMI.TTF', 'C:\\Windows\\Fonts\\LSANS.TTF', 'C:\\Windows\\Fonts\\segoeuib.ttf', 'C:\\Windows\\Fonts\\TCCEB.TTF', 'C:\\Windows\\Fonts\\segoescb.ttf', 'C:\\Windows\\Fonts\\seguisym.ttf', 'C:\\Windows\\Fonts\\ARIALN.TTF', 'C:\\Windows\\Fonts\\GOUDOSB.TTF', 'C:\\Windows\\Fonts\\HANBatangExtBB.ttf', 'C:\\Windows\\Fonts\\PALSCRI.TTF', 'C:\\Windows\\Fonts\\BRADHITC.TTF', 'C:\\Windows\\Fonts\\GILLUBCD.TTF', 'C:\\Windows\\Fonts\\constan.ttf', 'C:\\Windows\\Fonts\\FRAHV.TTF', 'C:\\W
# ...

# %%
import matplotlib.pyplot as plt
import platform
if platform.system() == 'Windows':
    plt.rc('font', family='Malgun Gothic')
else:
    plt.rc('font', family='AppleGothic')
numbers = [214, 2312, 1031, 1233]
blood_type = ['A형', 'B형', 'AB형', 'O형']
plt.axis('equal') # 파이 차트를 원형으로 그려줌
plt.pie(numbers, labels=blood_type, autopct='%.1f%%')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
y1 = [0.59705847, 0.25786401, 0.63213726, 0.63287317, 0.73791151]
y2 = [1.19411694, 0.51572803, 1.26427451, 1.26574635, 1.47582302]
y3 = [0.86793828, 0.07563408, 0.67670068, 0.78932712, 0.00436943] 
y4 = [0.43396914, 0.03781704, 0.33835034, 0.39466356, 0.00218471]

fig, axes = plt.subplots(2,2,figsize=(8,6), sharex=True, sharey=True)
fig.suptitle('figure title', fontsize=15)

plt.subplot(2,2,1)
plt.plot(x,y1)
plt.title('plot 1')

plt.subplot(2,2,2)
plt.plot(x,y2)
plt.title('plot 2')

plt.subplot(2,2,3)
plt.plot(x,y3)
plt.title('plot 3')

plt.subplot(2,2,4)
plt.plot(x,y4)
plt.title('plot 4')
# Out:
# Text(0.5, 1.0, 'plot 4')

# %%
import seaborn as sns
anscombe = sns.load_dataset('anscombe')
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

dataset_1 = anscombe[anscombe['dataset'] == 'I']
dataset_2 = anscombe[anscombe['dataset'] == 'II']
dataset_3 = anscombe[anscombe['dataset'] == 'III']
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

fig=plt.figure()
axes1 = fig.add_subplot(2,2,1)
axes1.plot(dataset_1['x'], dataset_1['y'], 'o')
axes1.set_title('dataset_1')

axes2 = fig.add_subplot(2,2,2)
axes2.plot(dataset_2['x'], dataset_2['y'], 'o')
axes2.set_title('dataset_2')

axes3 = fig.add_subplot(2,2,3)
axes3.plot(dataset_3['x'], dataset_3['y'], 'o')
axes3.set_title('dataset_3')

axes4 = fig.add_subplot(2,2,4)
axes4.plot(dataset_4['x'], dataset_4['y'], 'o')
axes4.set_title('dataset_4')

fig.suptitle('Anscombe Data')
fig.tight_layout()
plt.show()

# %%
import seaborn as sns
tips = sns.load_dataset('tips')
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1, 1, 1)
axes1.scatter(tips['total_bill'], tips['tip'])
axes1.set_title('Scatterplot of Total Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
plt.scatter(tips['total_bill'], tips['tip'])
plt.title('Scatterplot of Total Bill vs Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# %%
def recode_sex(sex):
    if sex == 'Female':
        return 0
    else:
        return 1

tips['sex_color'] = tips['sex'].apply(recode_sex)
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1, 1, 1)
axes1.scatter(
    x=tips['total_bill'],
    y=tips['tip'],
    s=tips['size'] * 10,
    c=tips['sex_color'],
    alpha=0.5)

axes1.set_title('Total Bill vs Tip Colored by Sex and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips = sns.load_dataset('tips')
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], hist=True, kde=True)
ax.set_title('Total Bill Histogram with Density Plot')
# Out:
# C:\Users\q\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Total Bill Histogram with Density Plot')

# %%
ax = plt.subplots()
ax = sns.kdeplot(x=tips['total_bill'],
y=tips['tip'],
shade=True)
ax.set_title('Kernel Density Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
import pandas as pd

df1=pd.read_csv('C:\jupiterworkspace\pandas\data/concat_1.csv')
df2=pd.read_csv('C:\jupiterworkspace\pandas\data/concat_2.csv')
df3=pd.read_csv('C:\jupiterworkspace\pandas\data/concat_3.csv')

row_concat = pd.concat([df1, df2, df3])
print(row_concat)
# Out:
#      A    B    C    D
# 0   a0   b0   c0   d0
# 1   a1   b1   c1   d1
# 2   a2   b2   c2   d2
# 3   a3   b3   c3   d3
# 0   a4   b4   c4   d4
# 1   a5   b5   c5   d5
# 2   a6   b6   c6   d6
# 3   a7   b7   c7   d7
# 0   a8   b8   c8   d8
# 1   a9   b9   c9   d9
# 2  a10  b10  c10  d10
# 3  a11  b11  c11  d11

# %%
new_row_series = pd.Series(['n1', 'n2', 'n3', 'n4'])
print(new_row_series)
print(pd.concat([df1, new_row_series]))
# Out:
# 0    n1
# 1    n2
# 2    n3
# 3    n4
# dtype: object
#      A    B    C    D    0
# 0   a0   b0   c0   d0  NaN
# 1   a1   b1   c1   d1  NaN
# 2   a2   b2   c2   d2  NaN
# 3   a3   b3   c3   d3  NaN
# 0  NaN  NaN  NaN  NaN   n1
# 1  NaN  NaN  NaN  NaN   n2
# 2  NaN  NaN  NaN  NaN   n3
# 3  NaN  NaN  NaN  NaN   n4
